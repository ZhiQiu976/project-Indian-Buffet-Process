# %%
# https://github.com/jaehyunjoo/IBP_Linear_Gaussian_Latent_Factor_Model

# %%
# %run demo.py
# Out:
# ...
# Initializing.....................
# Emulate Infinite Factor Model with the upperbound of K = 6
# Data shape: Obs = 100	 Dim = 36
# K = 6	Likelihood = -29291.038052
# alpha = 1.000000	sigma_x = 0.500000	sigma_a = 1.000000
# ...
# Iteration 1: K = 6	logLik = -4377.580426
# alpha = 0.524940	sigma_x = 0.743427	sigma_a = 0.983165
# 	Latent feature count: [15 16 13  2  6  7]
# Iteration 2: K = 4	logLik = -4199.568074
# alpha = 1.796056	sigma_x = 0.718729	sigma_a = 0.973410
# 	Latent feature count: [ 8 10  1  8]
# Iteration 3: K = 4	logLik = -4137.452087
# alpha = 0.428949	sigma_x = 0.677773	sigma_a = 0.969652
# 	Latent feature count: [10 11  4  9]
# Iteration 4: K = 4	logLik = -4013.263756
# alpha = 0.967512	sigma_x = 0.680985	sigma_a = 0.997706
# 	Latent feature count: [13 12  5  9]
# Iteration 5: K = 4	logLik = -3917.407052
# alpha = 0.955729	sigma_x = 0.653484	sigma_a = 1.024683
# 	Latent feature count: [15 14  9 10]
# Iteration 6: K = 4	logLik = -3744.864485
# ...

# %% [markdown]
# ![image](IBP_meanA.png)
# ![image](Image_Examples.png)
# ![image](Original_Latent_Features.png)

# %% [markdown]
# ![image](Trace_params.png)

# %% [markdown]
# This Python code package implements a linear-Gaussian latent factor model using an IBP (Indian buffet process) prior as illustrated in Griffiths and Ghahramani (2011).
#
# It uses a truncated IBP prior that has an upper bound of the number of latent features K. The real-valued latent feactures were implemented using a slice sampling based on Neal (2003).

# %% [markdown]
# The demo is based on a simulated data set consisting of 6x6 images in Griffiths and Ghahramani (2011).
#
# Default setting: used 100 6x6 images with an upper bound of K = 6 via 1000 MCMC iterations.
#
# Resuting outputs will be saved in a separate folder and visualized using David Andrzejewski's code (scaledimage.py) that mimics MATLAB imagesc.
